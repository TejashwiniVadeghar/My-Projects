# %% [markdown]
# <a href="https://colab.research.google.com/github/TejashwiniVadeghar/My-Projects/blob/main/PP1_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
# reading features list
with open("/content/drive/My Drive/db/kddcup.names", 'r') as f:
	print(f.read())
# Out:
# back,buffer_overflow,ftp_write,guess_passwd,imap,ipsweep,land,loadmodule,multihop,neptune,nmap,normal,perl,phf,pod,portsweep,rootkit,satan,smurf,spy,teardrop,warezclient,warezmaster.
# duration: continuous.
# protocol_type: symbolic.
# service: symbolic.
# flag: symbolic.
# src_bytes: continuous.
# dst_bytes: continuous.
# land: symbolic.
# wrong_fragment: continuous.
# urgent: continuous.
# hot: continuous.
# num_failed_logins: continuous.
# logged_in: symbolic.
# num_compromised: continuous.
# root_shell: continuous.
# su_attempted: continuous.
# num_root: continuous.
# num_file_creations: continuous.
# num_shells: continuous.
# num_access_files: continuous.
# num_outbound_cmds: continuous.
# is_host_login: symbolic.
# is_guest_login: symbolic.
# count: continuous.
# srv_count: continuous.
# serror_rate: continuous.
# srv_serror_rate: continuous.
# rerror_rate: continuous.
# srv_rerror_rate: continuous.
# same_srv_rate: continuous.
# diff_srv_rate: continuous.
# srv_diff_host_rate: continuous.
# dst_host_count: continuous.
# dst_host_srv_count: continuous.
# dst_host_same_srv_rate: continuous.
# dst_host_diff_srv_rate: continuous.
# dst_host_same_src_port_rate: continuous.
# dst_host_srv_diff_host_rate: continuous.
# dst_host_serror_rate: continuous.
# dst_host_srv_serror_rate: continuous.
# dst_host_rerror_rate: continuous.
# dst_host_srv_rerror_rate: continuous.

# %%
cols="""duration,
protocol_type,
service,
flag,
src_bytes,
dst_bytes,
land,
wrong_fragment,
urgent,
hot,
num_failed_logins,
logged_in,
num_compromised,
root_shell,
su_attempted,
num_root,
num_file_creations,
num_shells,
num_access_files,
num_outbound_cmds,
is_host_login,
is_guest_login,
count,
srv_count,
serror_rate,
srv_serror_rate,
rerror_rate,
srv_rerror_rate,
same_srv_rate,
diff_srv_rate,
srv_diff_host_rate,
dst_host_count,
dst_host_srv_count,
dst_host_same_srv_rate,
dst_host_diff_srv_rate,
dst_host_same_src_port_rate,
dst_host_srv_diff_host_rate,
dst_host_serror_rate,
dst_host_srv_serror_rate,
dst_host_rerror_rate,
dst_host_srv_rerror_rate"""

columns=[]
for c in cols.split(','):
    if(c.strip()):
       columns.append(c.strip())

columns.append('target')
#print(columns)
print(len(columns))
# Out:
# 42

# %%
with open("/content/drive/MyDrive/db/training_attack_types",'r') as f:
    print(f.read())
# Out:
# back dos
# buffer_overflow u2r
# ftp_write r2l
# guess_passwd r2l
# imap r2l
# ipsweep probe
# land dos
# loadmodule u2r
# multihop r2l
# neptune dos
# nmap probe
# perl u2r
# phf r2l
# pod dos
# portsweep probe
# rootkit u2r
# satan probe
# smurf dos
# spy r2l
# teardrop dos
# warezclient r2l
# warezmaster r2l

# %%
attacks_types = {
    'normal': 'normal',
'back': 'dos',
'buffer_overflow': 'u2r',
'ftp_write': 'r2l',
'guess_passwd': 'r2l',
'imap': 'r2l',
'ipsweep': 'probe',
'land': 'dos',
'loadmodule': 'u2r',
'multihop': 'r2l',
'neptune': 'dos',
'nmap': 'probe',
'perl': 'u2r',
'phf': 'r2l',
'pod': 'dos',
'portsweep': 'probe',
'rootkit': 'u2r',
'satan': 'probe',
'smurf': 'dos',
'spy': 'r2l',
'teardrop': 'dos',
'warezclient': 'r2l',
'warezmaster': 'r2l',
}

# %%
path = "/content/drive/MyDrive/db/kddcup.data_10_percent.gz"
df = pd.read_csv(path,names=columns)

#Adding Attack Type column
df['Attack Type'] = df.target.apply(lambda r:attacks_types[r[:-1]])

df.head()
# Out:
#    duration protocol_type  ...   target Attack Type
# 0         0           tcp  ...  normal.      normal
# 1         0           tcp  ...  normal.      normal
# 2         0           tcp  ...  normal.      normal
# 3         0           tcp  ...  normal.      normal
# 4         0           tcp  ...  normal.      normal
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (494021, 43)

# %%
df['target'].value_counts()
# Out:
# smurf.              280790
# neptune.            107201
# normal.              97278
# back.                 2203
# satan.                1589
# ipsweep.              1247
# portsweep.            1040
# warezclient.          1020
# teardrop.              979
# pod.                   264
# nmap.                  231
# guess_passwd.           53
# buffer_overflow.        30
# land.                   21
# warezmaster.            20
# imap.                   12
# rootkit.                10
# loadmodule.              9
# ftp_write.               8
# multihop.                7
# phf.                     4
# perl.                    3
# spy.                     2
# Name: target, dtype: int64

# %%
df['Attack Type'].value_counts()
# Out:
# dos       391458
# normal     97278
# probe       4107
# r2l         1126
# u2r           52
# Name: Attack Type, dtype: int64

# %%
df.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# srv_serror_rate                float64
# rerror_rate                    float64
# srv_rerror_rate                float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# srv_diff_host_rate             float64
# dst_host_count                   int64
# dst_host_srv_count               int64
# dst_host_same_srv_rate         float64
# dst_host_diff_srv_rate         float64
# dst_host_same_src_port_rate    float64
# dst_host_srv_diff_host_rate    float64
# dst_host_serror_rate           float64
# dst_host_srv_serror_rate       float64
# dst_host_rerror_rate           float64
# dst_host_srv_rerror_rate       float64
# target                          object
# Attack Type                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_diff_host_rate    0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# target                         0
# Attack Type                    0
# dtype: int64

# %%
#Finding categorical features
num_cols = df._get_numeric_data().columns

cate_cols = list(set(df.columns)-set(num_cols))
cate_cols.remove('target')
cate_cols.remove('Attack Type')

cate_cols
# Out:
# ['flag', 'service', 'protocol_type']

# %%
def bar_graph(feature):
    df[feature].value_counts().plot(kind="bar")

# %%
bar_graph('protocol_type')

# %%
plt.figure(figsize=(15,3))
bar_graph('service')

# %%
bar_graph('flag')

# %%
bar_graph('logged_in')

# %%
bar_graph('target')

# %%
bar_graph('Attack Type')

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'target', 'Attack Type'],
#       dtype='object')

# %%
df = df.dropna('columns')# drop columns with NaN

df = df[[col for col in df if df[col].nunique() > 1]]# keep columns where there are more than 1 unique values

corr = df.corr()

plt.figure(figsize=(15,12))

sns.heatmap(corr)

plt.show()

# %%
df['num_root'].corr(df['num_compromised'])
# Out:
# 0.9938277978737916

# %%
df['srv_serror_rate'].corr(df['serror_rate'])
# Out:
# 0.998361507272553

# %%
df['srv_count'].corr(df['count'])
# Out:
# 0.9436670688882645

# %%
df['srv_rerror_rate'].corr(df['rerror_rate'])
# Out:
# 0.9947309539818242

# %%
df['dst_host_same_srv_rate'].corr(df['dst_host_srv_count'])
# Out:
# 0.9736854572953835

# %%
df['dst_host_srv_serror_rate'].corr(df['dst_host_serror_rate'])
# Out:
# 0.9981559173373293

# %%
df['dst_host_srv_rerror_rate'].corr(df['dst_host_rerror_rate'])
# Out:
# 0.9848038371110285

# %%
df['dst_host_same_srv_rate'].corr(df['same_srv_rate'])
# Out:
# 0.9278080342690969

# %%
df['dst_host_srv_count'].corr(df['same_srv_rate'])
# Out:
# 0.8989546630323716

# %%
df['dst_host_same_src_port_rate'].corr(df['srv_count'])
# Out:
# 0.944926367678324

# %%
df['dst_host_serror_rate'].corr(df['serror_rate'])
# Out:
# 0.9986729680104371

# %%
df['dst_host_serror_rate'].corr(df['srv_serror_rate'])
# Out:
# 0.9978353003739603

# %%
df['dst_host_srv_serror_rate'].corr(df['serror_rate'])
# Out:
# 0.997849248567986

# %%
df['dst_host_srv_serror_rate'].corr(df['srv_serror_rate'])
# Out:
# 0.999304109185027

# %%
df['dst_host_rerror_rate'].corr(df['rerror_rate'])
# Out:
# 0.986994792495618

# %%
df['dst_host_rerror_rate'].corr(df['srv_rerror_rate'])
# Out:
# 0.9821663427308264

# %%
df['dst_host_srv_rerror_rate'].corr(df['rerror_rate'])
# Out:
# 0.9851995540751695

# %%
df['dst_host_srv_rerror_rate'].corr(df['srv_rerror_rate'])
# Out:
# 0.9865705438845764

# %%
#This variable is highly correlated with num_compromised and should be ignored for analysis.
#(Correlation = 0.9938277978738366)
df.drop('num_root',axis = 1,inplace = True)

#This variable is highly correlated with serror_rate and should be ignored for analysis.
#(Correlation = 0.9983615072725952)
df.drop('srv_serror_rate',axis = 1,inplace = True)

#This variable is highly correlated with rerror_rate and should be ignored for analysis.
#(Correlation = 0.9947309539817937)
df.drop('srv_rerror_rate',axis = 1, inplace=True)

#This variable is highly correlated with srv_serror_rate and should be ignored for analysis.
#(Correlation = 0.9993041091850098)
df.drop('dst_host_srv_serror_rate',axis = 1, inplace=True)

#This variable is highly correlated with rerror_rate and should be ignored for analysis.
#(Correlation = 0.9869947924956001)
df.drop('dst_host_serror_rate',axis = 1, inplace=True)

#This variable is highly correlated with srv_rerror_rate and should be ignored for analysis.
#(Correlation = 0.9821663427308375)
df.drop('dst_host_rerror_rate',axis = 1, inplace=True)

#This variable is highly correlated with rerror_rate and should be ignored for analysis.
#(Correlation = 0.9851995540751249)
df.drop('dst_host_srv_rerror_rate',axis = 1, inplace=True)

#This variable is highly correlated with srv_rerror_rate and should be ignored for analysis.
#(Correlation = 0.9865705438845669)
df.drop('dst_host_same_srv_rate',axis = 1, inplace=True)

# %%
df.head()
# Out:
#    duration protocol_type  ...   target Attack Type
# 0         0           tcp  ...  normal.      normal
# 1         0           tcp  ...  normal.      normal
# 2         0           tcp  ...  normal.      normal
# 3         0           tcp  ...  normal.      normal
# 4         0           tcp  ...  normal.      normal
#
# [5 rows x 33 columns]

# %%
df.head()
# Out:
#    duration protocol_type  ...   target Attack Type
# 0         0           tcp  ...  normal.      normal
# 1         0           tcp  ...  normal.      normal
# 2         0           tcp  ...  normal.      normal
# 3         0           tcp  ...  normal.      normal
# 4         0           tcp  ...  normal.      normal
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_file_creations', 'num_shells', 'num_access_files',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate', 'rerror_rate',
#        'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
#        'dst_host_count', 'dst_host_srv_count', 'dst_host_diff_srv_rate',
#        'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'target',
#        'Attack Type'],
#       dtype='object')

# %%
df_std = df.std()
df_std = df_std.sort_values(ascending = True)
df_std
# Out:
# urgent                              0.005510
# land                                0.006673
# su_attempted                        0.007793
# root_shell                          0.010551
# num_shells                          0.011020
# num_failed_logins                   0.015520
# num_access_files                    0.036482
# is_guest_login                      0.037211
# dst_host_srv_diff_host_rate         0.042133
# diff_srv_rate                       0.082205
# num_file_creations                  0.096416
# dst_host_diff_srv_rate              0.109259
# wrong_fragment                      0.134805
# srv_diff_host_rate                  0.142397
# rerror_rate                         0.231623
# logged_in                           0.355345
# serror_rate                         0.380717
# same_srv_rate                       0.388189
# dst_host_same_src_port_rate         0.481309
# hot                                 0.782103
# num_compromised                     1.798326
# dst_host_count                     64.745380
# dst_host_srv_count                106.040437
# count                             213.147412
# srv_count                         246.322817
# duration                          707.746472
# dst_bytes                       33040.001252
# src_bytes                      988218.101045
# dtype: float64

# %%
df['protocol_type'].value_counts()
# Out:
# icmp    283602
# tcp     190065
# udp      20354
# Name: protocol_type, dtype: int64

# %%
pmap = {'icmp':0,'tcp':1,'udp':2}
df['protocol_type'] = df['protocol_type'].map(pmap)

# %%
df['flag'].value_counts()
# Out:
# SF        378440
# S0         87007
# REJ        26875
# RSTR         903
# RSTO         579
# SH           107
# S1            57
# S2            24
# RSTOS0        11
# S3            10
# OTH            8
# Name: flag, dtype: int64

# %%
fmap = {'SF':0,'S0':1,'REJ':2,'RSTR':3,'RSTO':4,'SH':5 ,'S1':6 ,'S2':7,'RSTOS0':8,'S3':9 ,'OTH':10}
df['flag'] = df['flag'].map(fmap)

# %%
df.head()
# Out:
#    duration  protocol_type  ...   target  Attack Type
# 0         0              1  ...  normal.       normal
# 1         0              1  ...  normal.       normal
# 2         0              1  ...  normal.       normal
# 3         0              1  ...  normal.       normal
# 4         0              1  ...  normal.       normal
#
# [5 rows x 33 columns]

# %%
df.drop('service',axis = 1,inplace= True)

# %%
df.shape
# Out:
# (494021, 32)

# %%
df.head()
# Out:
#    duration  protocol_type  ...   target  Attack Type
# 0         0              1  ...  normal.       normal
# 1         0              1  ...  normal.       normal
# 2         0              1  ...  normal.       normal
# 3         0              1  ...  normal.       normal
# 4         0              1  ...  normal.       normal
#
# [5 rows x 32 columns]

# %%
df.dtypes
# Out:
# duration                         int64
# protocol_type                    int64
# flag                             int64
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# serror_rate                    float64
# rerror_rate                    float64
# same_srv_rate                  float64
# diff_srv_rate                  float64
# srv_diff_host_rate             float64
# dst_host_count                   int64
# dst_host_srv_count               int64
# dst_host_diff_srv_rate         float64
# dst_host_same_src_port_rate    float64
# dst_host_srv_diff_host_rate    float64
# target                          object
# Attack Type                     object
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# %%
df = df.drop(['target',], axis=1)
print(df.shape)

# Target variable and train set
Y = df[['Attack Type']]
X = df.drop(['Attack Type',], axis=1)

sc = MinMaxScaler()
X = sc.fit_transform(X)

# Split test and train data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (494021, 31)
# (330994, 30) (163027, 30)
# (330994, 1) (163027, 1)

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

# %%
model1 = GaussianNB()

# %%
start_time = time.time()
model1.fit(X_train, Y_train.values.ravel())
end_time = time.time()
print("Training time: ",end_time-start_time)
# Out:
# Training time:  0.6252999305725098

# %%
start_time = time.time()
Y_test_pred1 = model1.predict(X_test)
end_time = time.time()

# %%
print("Testing time: ",end_time-start_time)
# Out:
# Testing time:  0.16106009483337402

# %%
print("Train score is:", model1.score(X_train, Y_train))
print("Test score is:",model1.score(X_test,Y_test))
# Out:
# Train score is: 0.8795114110829804
# Test score is: 0.8790384414851528

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

# %%
def fun():
    model = Sequential()


    model.add(Dense(30,input_dim =30,activation = 'relu',kernel_initializer='random_uniform'))


    model.add(Dense(1,activation='sigmoid',kernel_initializer='random_uniform'))


    model.add(Dense(5,activation='softmax'))


    model.compile(loss ='categorical_crossentropy',optimizer = 'adam',metrics = ['accuracy'])

    return model

# %%
model7 = KerasClassifier(build_fn=fun,epochs=100,batch_size=64)

# %%
start = time.time()
model7.fit(X_train, Y_train.values.ravel())
end = time.time()
# Out:
# Epoch 1/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.3171 - accuracy: 0.9415
# Epoch 2/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0785 - accuracy: 0.9846
# Epoch 3/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0649 - accuracy: 0.9847
# Epoch 4/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0608 - accuracy: 0.9847
# Epoch 5/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0581 - accuracy: 0.9847
# Epoch 6/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0562 - accuracy: 0.9847
# Epoch 7/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0548 - accuracy: 0.9847
# Epoch 8/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0538 - accuracy: 0.9847
# Epoch 9/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0529 - accuracy: 0.9847
# Epoch 10/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0522 - accuracy: 0.9847
# Epoch 11/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0504 - accuracy: 0.9847
# Epoch 12/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0402 - accuracy: 0.9859
# Epoch 13/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0288 - accuracy: 0.9906
# Epoch 14/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0235 - accuracy: 0.9944
# Epoch 15/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0204 - accuracy: 0.9954
# Epoch 16/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0188 - accuracy: 0.9959
# Epoch 17/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0176 - accuracy: 0.9961
# Epoch 18/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0169 - accuracy: 0.9962
# Epoch 19/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0164 - accuracy: 0.9962
# Epoch 20/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0158 - accuracy: 0.9962
# Epoch 21/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0155 - accuracy: 0.9963
# Epoch 22/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0152 - accuracy: 0.9963
# Epoch 23/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0151 - accuracy: 0.9963
# Epoch 24/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0149 - accuracy: 0.9964
# Epoch 25/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0148 - accuracy: 0.9963
# Epoch 26/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0146 - accuracy: 0.9963
# Epoch 27/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0145 - accuracy: 0.9964
# Epoch 28/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0143 - accuracy: 0.9964
# Epoch 29/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0141 - accuracy: 0.9964
# Epoch 30/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0140 - accuracy: 0.9963
# Epoch 31/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0139 - accuracy: 0.9965
# Epoch 32/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0137 - accuracy: 0.9965
# Epoch 33/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0136 - accuracy: 0.9965
# Epoch 34/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0135 - accuracy: 0.9965
# Epoch 35/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0134 - accuracy: 0.9965
# Epoch 36/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0132 - accuracy: 0.9965
# Epoch 37/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0131 - accuracy: 0.9965
# Epoch 38/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0130 - accuracy: 0.9965
# Epoch 39/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0130 - accuracy: 0.9965
# Epoch 40/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0129 - accuracy: 0.9966
# Epoch 41/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 42/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0127 - accuracy: 0.9966
# Epoch 43/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 44/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0122 - accuracy: 0.9967
# Epoch 45/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0120 - accuracy: 0.9967
# Epoch 46/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0118 - accuracy: 0.9968
# Epoch 47/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0117 - accuracy: 0.9967
# Epoch 48/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0115 - accuracy: 0.9968
# Epoch 49/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0113 - accuracy: 0.9968
# Epoch 50/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0112 - accuracy: 0.9968
# Epoch 51/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0111 - accuracy: 0.9969
# Epoch 52/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0109 - accuracy: 0.9969
# Epoch 53/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0108 - accuracy: 0.9969
# Epoch 54/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0107 - accuracy: 0.9970
# Epoch 55/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0106 - accuracy: 0.9969
# Epoch 56/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0105 - accuracy: 0.9970
# Epoch 57/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0104 - accuracy: 0.9969
# Epoch 58/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0102 - accuracy: 0.9970
# Epoch 59/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0102 - accuracy: 0.9970
# Epoch 60/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0101 - accuracy: 0.9970
# Epoch 61/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0100 - accuracy: 0.9969
# Epoch 62/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0099 - accuracy: 0.9970
# Epoch 63/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0098 - accuracy: 0.9970
# Epoch 64/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0097 - accuracy: 0.9971
# Epoch 65/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0097 - accuracy: 0.9971
# Epoch 66/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0095 - accuracy: 0.9971
# Epoch 67/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 68/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 69/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0093 - accuracy: 0.9973
# Epoch 70/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0093 - accuracy: 0.9974
# Epoch 71/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0092 - accuracy: 0.9976
# Epoch 72/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0092 - accuracy: 0.9975
# Epoch 73/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0091 - accuracy: 0.9977
# Epoch 74/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0091 - accuracy: 0.9978
# Epoch 75/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0090 - accuracy: 0.9978
# Epoch 76/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0090 - accuracy: 0.9979
# Epoch 77/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 78/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0089 - accuracy: 0.9980
# Epoch 79/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0088 - accuracy: 0.9980
# Epoch 80/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0088 - accuracy: 0.9980
# Epoch 81/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0087 - accuracy: 0.9980
# Epoch 82/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0087 - accuracy: 0.9982
# Epoch 83/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0086 - accuracy: 0.9981
# Epoch 84/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 85/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0085 - accuracy: 0.9983
# Epoch 86/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0085 - accuracy: 0.9983
# Epoch 87/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0084 - accuracy: 0.9982
# Epoch 88/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 89/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 90/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 91/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0083 - accuracy: 0.9984
# Epoch 92/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0082 - accuracy: 0.9985
# Epoch 93/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0081 - accuracy: 0.9985
# Epoch 94/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0081 - accuracy: 0.9984
# Epoch 95/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0080 - accuracy: 0.9986
# Epoch 96/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0081 - accuracy: 0.9985
# Epoch 97/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0080 - accuracy: 0.9985
# Epoch 98/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 99/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0079 - accuracy: 0.9985
# Epoch 100/100
# 5172/5172 [==============================] - 6s 1ms/step - loss: 0.0079 - accuracy: 0.9985

# %%
print('Training time')
print((end-start))
# Out:
# Training time
# 580.339346408844

# %%
start_time = time.time()
Y_test_pred7 = model7.predict(X_test)
end_time = time.time()

# %%
print("Testing time: ",end_time-start_time)
# Out:
# Testing time:  1.4566235542297363

# %%
start_time = time.time()
Y_train_pred7 = model7.predict(X_train)
end_time = time.time()

# %%
accuracy_score(Y_train,Y_train_pred7)
# Out:
# 0.9986102467114207

# %%
accuracy_score(Y_test,Y_test_pred7)
# Out:
# 0.9982211535512523

# %%
from sklearn.svm import SVC

# %%
model4 = SVC(gamma = 'scale')

# %%
start_time = time.time()
model4.fit(X_train, Y_train.values.ravel())
end_time = time.time()

# %%
print("Training time: ",end_time-start_time)
# Out:
# Training time:  166.64044189453125

# %%
start_time = time.time()
Y_test_pred4 = model4.predict(X_test)
end_time = time.time()

# %%
print("Testing time: ",end_time-start_time)
# Out:
# Testing time:  46.17637085914612

# %%
print("Train score is:", model4.score(X_train, Y_train))
print("Test score is:", model4.score(X_test,Y_test))
# Out:
# Train score is: 0.9987552644458811
# Test score is: 0.9987916112055059
